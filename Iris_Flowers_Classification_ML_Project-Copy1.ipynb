# %% [markdown]
# # Sparks Foundation Internship Project

# %% [markdown]
# # Prediction Using Unsuperwised ML

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris_df=pd.read_csv('Iris.csv')

# %%
#basic Information regarding data
iris_df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_df.head(10)
#Checking top ten records of the dataset
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
#visulising the data set features to find pattern to solve our task
plt.scatter(iris_df['PetalLengthCm'],iris_df['PetalWidthCm'])
plt.show()

# %%
#using seaborn lib to visualise 2 features base don the target variable
sns.set_style('whitegrid')
sns.FacetGrid(iris_df,hue='Species').map(plt.scatter,'PetalLengthCm','PetalWidthCm').add_legend()
plt.show()

# %%
#Iris setosa can be identified easily as they grouped seperataly while iris versicolor and iris virginica are mixed  little

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris_df,hue='Species').map(plt.scatter,'SepalLengthCm','SepalWidthCm').add_legend()
plt.show()

# %%
#Length of the iris setosa is not mixed with iris versicolor and iris virginica , while iris versicolor and iris virginica can have simillar length as they are mixed .

# %%
#pair plot gives the relationship between all the features distribution with each other
sns.pairplot(iris_df.drop(['Id'],axis=1),hue='Species')

# %%
#Taking difference of each feature with each other to get some more information and visualized it by using plots.
iris_df['Sepal_Diff']=iris_df['SepalLengthCm']-iris_df['SepalWidthCm']
iris_df['Petal_Diff']=iris_df['PetalLengthCm']-iris_df['PetalWidthCm']
iris_df['Sepal_Petal_Length_Diff']=iris_df['SepalLengthCm']-iris_df['PetalLengthCm']
iris_df['Sepal_Petal_Width_Diff']=iris_df['SepalWidthCm']-iris_df['PetalWidthCm']
iris_df['Sepal_Petal_len_width_diff']=iris_df['SepalLengthCm']-iris_df['PetalWidthCm']
iris_df['Sepal_Petal_width_len_diff']=iris_df['PetalLengthCm']-iris_df['SepalWidthCm']

# %%
iris_df
# Out:
#       Id  SepalLengthCm  ...  Sepal_Petal_len_width_diff  Sepal_Petal_width_len_diff
# 0      1            5.1  ...                         4.9                        -2.1
# 1      2            4.9  ...                         4.7                        -1.6
# 2      3            4.7  ...                         4.5                        -1.9
# 3      4            4.6  ...                         4.4                        -1.6
# 4      5            5.0  ...                         4.8                        -2.2
# ..   ...            ...  ...                         ...                         ...
# 145  146            6.7  ...                         4.4                         2.2
# 146  147            6.3  ...                         4.4                         2.5
# 147  148            6.5  ...                         4.5                         2.2
# 148  149            6.2  ...                         3.9                         2.0
# ...

# %%
sns.pairplot(iris_df[['Species','Sepal_Diff','Petal_Diff','Sepal_Petal_Length_Diff','Sepal_Petal_Width_Diff','Sepal_Petal_len_width_diff','Sepal_Petal_width_len_diff']],hue='Species');
